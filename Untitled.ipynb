# %%
import os

print(os.listdir("gunny bags.v1i.coco/train"))
# Out:
# ['.ipynb_checkpoints', '01_jpg.rf.a4e6f59b3249c732e35d0710962f30f0.jpg', '01_jpg.rf.c1fba04beca72211f6c2f5be14e1c902.jpg', '02_jpg.rf.45e5079615ed9de70371e825b2ce256a.jpg', '02_jpg.rf.4d995b4edd2fcbd4b8945fa51178ed66.jpg', '02_jpg.rf.c9962acde76ea89bf861ac925137c3c1.jpg', '03_jpg.rf.3e8761369d543a2585e8e926b8c3628e.jpg', '03_jpg.rf.88b7854eef4b950a85837cd7a6d30445.jpg', '04_jpg.rf.1eef0f60b5d05af6e7b4caac9ec1435e.jpg', '04_jpg.rf.356a135cebcc71bbb2913816093dc773.jpg', '04_jpg.rf.e147beda04f061da531a7faaadda27b0.jpg', '05_jpg.rf.06f054d0457a007ee63d82c7018b2a28.jpg', '06_jpg.rf.6a75c20681313d229674461695d5ba19.jpg', '06_jpg.rf.72d8835f3ee3c767e1833fd7f18cd5c7.jpg', '07_jpg.rf.72a1c49e2ae1981c8eb3f917e8e8b355.jpg', '07_jpg.rf.ab0ca07f9d906a1b5ed036704d526303.jpg', '07_jpg.rf.f07d4a86602a0dc48ea980d7c5e3d82f.jpg', '08_jpg.rf.04db3440d23886616994358e4f316a56.jpg', '08_jpg.rf.6df6358963dd624d8c4d5a0c15d144fb.jpg', '09_jpg.rf.40cfda91c755df71a627ceee361a2a4a.jpg', '09_jpg.rf.45c9983d1b0ba1
# ...

# %%
with open("gunny bags.v1i.coco/data.yaml", "r") as f:
    print(f.read())
# Out:
# path: C:/Users/ASUS/Documents/AI/smart_rice_system/gunny bags.v1i.coco
#
# train: train
# val: test
#
# nc: 1
#
# names:
#   0: gunny_bag

# %%
with open("gunny bags.v1i.coco/data.yaml", "r") as f:
    print(f.read())
# Out:
# path: C:/Users/ASUS/Documents/AI/smart_rice_system/gunny bags.v1i.coco
#
# train: train
# val: test
#
# nc: 1
#
# names:
#   0: gunny_bag

# %%
import os
print(os.listdir("gunny bags.v1i.coco"))
# Out:
# ['.ipynb_checkpoints', 'data.yaml', 'test', 'test.cache', 'train', 'train.cache', '_annotations.coco.json']

# %%
with open("gunny bags.v1i.coco/data.yaml", "r") as f:
    print(f.read())
# Out:
# path: C:/Users/ASUS/Documents/AI/smart_rice_system/gunny bags.v1i.coco
#
# train: train
# val: test
#
# nc: 1
#
# names:
#   0: gunny_bag

# %%
with open("gunny bags.v1i.coco/data.yaml", "r") as f:
    print(f.read())
# Out:
# path: C:/Users/ASUS/Documents/AI/smart_rice_system/gunny bags.v1i.coco
#
# train: train
# val: test
#
# nc: 1
#
# names:
#   0: gunny_bag

# %%
with open("gunny bags.v1i.coco/data.yaml", "r", encoding="utf-8") as f:
    content = f.read()

print("CONTENT:")
print(content)
# Out:
# CONTENT:
# path: C:/Users/ASUS/Documents/AI/smart_rice_system/gunny bags.v1i.coco
#
# train: train
# val: test
#
# nc: 1
#
# names:
#   0: gunny_bag

# %%
import os

print("TRAIN:", os.listdir("gunny bags.v1i.coco/train"))
print("TEST:", os.listdir("gunny bags.v1i.coco/test"))
# Out:
# TRAIN: ['.ipynb_checkpoints', '01_jpg.rf.a4e6f59b3249c732e35d0710962f30f0.jpg', '01_jpg.rf.c1fba04beca72211f6c2f5be14e1c902.jpg', '02_jpg.rf.45e5079615ed9de70371e825b2ce256a.jpg', '02_jpg.rf.4d995b4edd2fcbd4b8945fa51178ed66.jpg', '02_jpg.rf.c9962acde76ea89bf861ac925137c3c1.jpg', '03_jpg.rf.3e8761369d543a2585e8e926b8c3628e.jpg', '03_jpg.rf.88b7854eef4b950a85837cd7a6d30445.jpg', '04_jpg.rf.1eef0f60b5d05af6e7b4caac9ec1435e.jpg', '04_jpg.rf.356a135cebcc71bbb2913816093dc773.jpg', '04_jpg.rf.e147beda04f061da531a7faaadda27b0.jpg', '05_jpg.rf.06f054d0457a007ee63d82c7018b2a28.jpg', '06_jpg.rf.6a75c20681313d229674461695d5ba19.jpg', '06_jpg.rf.72d8835f3ee3c767e1833fd7f18cd5c7.jpg', '07_jpg.rf.72a1c49e2ae1981c8eb3f917e8e8b355.jpg', '07_jpg.rf.ab0ca07f9d906a1b5ed036704d526303.jpg', '07_jpg.rf.f07d4a86602a0dc48ea980d7c5e3d82f.jpg', '08_jpg.rf.04db3440d23886616994358e4f316a56.jpg', '08_jpg.rf.6df6358963dd624d8c4d5a0c15d144fb.jpg', '09_jpg.rf.40cfda91c755df71a627ceee361a2a4a.jpg', '09_jpg.rf.45c9983
# ...

# %%
import os

print("TRAIN:", os.listdir("gunny bags.v1i.coco/train"))
print("TEST:", os.listdir("gunny bags.v1i.coco/test"))
# Out:
# TRAIN: ['.ipynb_checkpoints', '01_jpg.rf.a4e6f59b3249c732e35d0710962f30f0.jpg', '01_jpg.rf.c1fba04beca72211f6c2f5be14e1c902.jpg', '02_jpg.rf.45e5079615ed9de70371e825b2ce256a.jpg', '02_jpg.rf.4d995b4edd2fcbd4b8945fa51178ed66.jpg', '02_jpg.rf.c9962acde76ea89bf861ac925137c3c1.jpg', '03_jpg.rf.3e8761369d543a2585e8e926b8c3628e.jpg', '03_jpg.rf.88b7854eef4b950a85837cd7a6d30445.jpg', '04_jpg.rf.1eef0f60b5d05af6e7b4caac9ec1435e.jpg', '04_jpg.rf.356a135cebcc71bbb2913816093dc773.jpg', '04_jpg.rf.e147beda04f061da531a7faaadda27b0.jpg', '05_jpg.rf.06f054d0457a007ee63d82c7018b2a28.jpg', '06_jpg.rf.6a75c20681313d229674461695d5ba19.jpg', '06_jpg.rf.72d8835f3ee3c767e1833fd7f18cd5c7.jpg', '07_jpg.rf.72a1c49e2ae1981c8eb3f917e8e8b355.jpg', '07_jpg.rf.ab0ca07f9d906a1b5ed036704d526303.jpg', '07_jpg.rf.f07d4a86602a0dc48ea980d7c5e3d82f.jpg', '08_jpg.rf.04db3440d23886616994358e4f316a56.jpg', '08_jpg.rf.6df6358963dd624d8c4d5a0c15d144fb.jpg', '09_jpg.rf.40cfda91c755df71a627ceee361a2a4a.jpg', '09_jpg.rf.45c9983
# ...

# %%
from ultralytics.data.utils import check_det_dataset

check_det_dataset("gunny bags.v1i.coco/data.yaml")
# Out:
# {'path': WindowsPath('C:/Users/ASUS/Documents/AI/smart_rice_system/gunny bags.v1i.coco'),
#  'train': 'C:\\Users\\ASUS\\Documents\\AI\\smart_rice_system\\gunny bags.v1i.coco\\train',
#  'val': 'C:\\Users\\ASUS\\Documents\\AI\\smart_rice_system\\gunny bags.v1i.coco\\test',
#  'nc': 1,
#  'names': {0: 'gunny_bag'},
#  'yaml_file': 'gunny bags.v1i.coco\\data.yaml',
#  'channels': 3}

# %%
import os

dataset_path = "gunny bags.v1i.coco"

print(os.listdir(dataset_path))
# Out:
# ['.ipynb_checkpoints', 'data.yaml', 'test', 'test.cache', 'train', 'train.cache', '_annotations.coco.json']

# %%
import os

print(os.listdir("gunny bags.v1i.coco/train")[:20])
# Out:
# ['.ipynb_checkpoints', '01_jpg.rf.a4e6f59b3249c732e35d0710962f30f0.jpg', '01_jpg.rf.c1fba04beca72211f6c2f5be14e1c902.jpg', '02_jpg.rf.45e5079615ed9de70371e825b2ce256a.jpg', '02_jpg.rf.4d995b4edd2fcbd4b8945fa51178ed66.jpg', '02_jpg.rf.c9962acde76ea89bf861ac925137c3c1.jpg', '03_jpg.rf.3e8761369d543a2585e8e926b8c3628e.jpg', '03_jpg.rf.88b7854eef4b950a85837cd7a6d30445.jpg', '04_jpg.rf.1eef0f60b5d05af6e7b4caac9ec1435e.jpg', '04_jpg.rf.356a135cebcc71bbb2913816093dc773.jpg', '04_jpg.rf.e147beda04f061da531a7faaadda27b0.jpg', '05_jpg.rf.06f054d0457a007ee63d82c7018b2a28.jpg', '06_jpg.rf.6a75c20681313d229674461695d5ba19.jpg', '06_jpg.rf.72d8835f3ee3c767e1833fd7f18cd5c7.jpg', '07_jpg.rf.72a1c49e2ae1981c8eb3f917e8e8b355.jpg', '07_jpg.rf.ab0ca07f9d906a1b5ed036704d526303.jpg', '07_jpg.rf.f07d4a86602a0dc48ea980d7c5e3d82f.jpg', '08_jpg.rf.04db3440d23886616994358e4f316a56.jpg', '08_jpg.rf.6df6358963dd624d8c4d5a0c15d144fb.jpg', '09_jpg.rf.40cfda91c755df71a627ceee361a2a4a.jpg']

# %%
import json

with open("gunny bags.v1i.coco/_annotations.coco.json", "r") as f:
    data = json.load(f)

print("Images:", len(data["images"]))
print("Annotations:", len(data["annotations"]))
print("Categories:", data["categories"])
# Out:
# Images: 220
# Annotations: 3756
# Categories: [{'id': 0, 'name': 'gunny-bag-KY7y', 'supercategory': 'none'}, {'id': 1, 'name': 'Counting  industry - v1 2024-06-18 6-04am', 'supercategory': 'gunny-bag-KY7y'}]

# %%
with open("gunny bags.v1i.coco/data.yaml", "r") as f:
    print(f.read())
# Out:
# path: C:/Users/ASUS/Documents/AI/smart_rice_system/gunny bags.v1i.coco
#
# train: train
# val: test
#
# nc: 1
#
# names:
#   0: gunny_bag

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")

model.train(
    data=r"C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v1i.coco\data.yaml",
    epochs=3,
    imgsz=640,
    batch=8
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.66 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.56  Python-3.13.5 torch-2.12.0+cpu CPU (11th Gen Intel Core i3-1115G4 @ 3.00GHz)
# ...

# %%
from ultralytics import YOLO

model = YOLO(r"C:\Users\ASUS\Documents\AI\smart_rice_system\runs\detect\train\weights\best.pt")

# %%
from ultralytics import YOLO

model = YOLO(r"C:\Users\ASUS\Documents\AI\smart_rice_system\runs\detect\train\weights\best.pt")

results = model.predict(
    source=r"C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v1i.coco\test\2_jpg.rf.204350f040ce5982a073ea6473fb2c7f.jpg",
    save=True,
    conf=0.25
)
# Out:
# image 1/1 C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v1i.coco\test\2_jpg.rf.204350f040ce5982a073ea6473fb2c7f.jpg: 640x640 (no detections), 228.7ms
# Speed: 19.5ms preprocess, 228.7ms inference, 19.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\Users\ASUS\Documents\AI\smart_rice_system\runs\detect\predict

# %%
results = model(
    r"C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v1i.coco\test\2_jpg.rf.204350f040ce5982a073ea6473fb2c7f.jpg"
)

print("Bags:", len(results[0].boxes))
# Out:
# image 1/1 C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v1i.coco\test\2_jpg.rf.204350f040ce5982a073ea6473fb2c7f.jpg: 640x640 2 suitcases, 158.5ms
# Speed: 7.2ms preprocess, 158.5ms inference, 16.8ms postprocess per image at shape (1, 3, 640, 640)
# Bags: 2

# %%
results = model(
    r"C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v1i.coco\test\2_jpg.rf.204350f040ce5982a073ea6473fb2c7f.jpg"
)

print("Bags:", len(results[0].boxes))
# Out:
# image 1/1 C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v1i.coco\test\2_jpg.rf.204350f040ce5982a073ea6473fb2c7f.jpg: 640x640 2 suitcases, 151.7ms
# Speed: 5.8ms preprocess, 151.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# Bags: 2

# %%
results = model.predict(
    source=r"C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v1i.coco\test\2_jpg.rf.204350f040ce5982a073ea6473fb2c7f.jpg",
    save=True
)
# Out:
# image 1/1 C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v1i.coco\test\2_jpg.rf.204350f040ce5982a073ea6473fb2c7f.jpg: 640x640 2 suitcases, 134.4ms
# Speed: 4.2ms preprocess, 134.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\Users\ASUS\Documents\AI\smart_rice_system\runs\detect\predict-2

# %%
from ultralytics import YOLO

model = YOLO(r"C:\Users\ASUS\Documents\AI\smart_rice_system\runs\detect\train\weights\best.pt")

results = model(
    r"C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v1i.coco\test\2_jpg.rf.204350f040ce5982a073ea6473fb2c7f.jpg"
)

count = len(results[0].boxes)

print(f"Total Gunny Bags: {count}")
# Out:
# image 1/1 C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v1i.coco\test\2_jpg.rf.204350f040ce5982a073ea6473fb2c7f.jpg: 640x640 (no detections), 117.8ms
# Speed: 3.7ms preprocess, 117.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# Total Gunny Bags: 0

# %%
import os
from ultralytics import YOLO

model = YOLO(r"C:\Users\ASUS\Documents\AI\smart_rice_system\runs\detect\train\weights\best.pt")

folder = r"C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v1i.coco\test"

for img in os.listdir(folder):
    if img.endswith(".jpg"):
        results = model(os.path.join(folder, img))
        print(img, "->", len(results[0].boxes), "bags")
# Out:
# image 1/1 C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v1i.coco\test\03_jpg.rf.28f0f34d85e921076eb357c9235167eb.jpg: 640x640 (no detections), 125.3ms
# Speed: 3.6ms preprocess, 125.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 03_jpg.rf.28f0f34d85e921076eb357c9235167eb.jpg -> 0 bags
#
# image 1/1 C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v1i.coco\test\05_jpg.rf.7716b4c7132c489a85ace622ce992bff.jpg: 640x640 (no detections), 108.5ms
# Speed: 3.9ms preprocess, 108.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# 05_jpg.rf.7716b4c7132c489a85ace622ce992bff.jpg -> 0 bags
#
# image 1/1 C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v1i.coco\test\10_jpg.rf.1f2384f6f130c4347e18d591b7aa5079.jpg: 640x640 (no detections), 130.4ms
# Speed: 3.6ms preprocess, 130.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# 10_jpg.rf.1f2384f6f130c4347e18d591b7aa5079.jpg -> 0 bags
#
# ...

# %%
import os
from ultralytics import YOLO

model = YOLO(r"C:\Users\ASUS\Documents\AI\smart_rice_system\runs\detect\train\weights\best.pt")

folder = r"C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v1i.coco\test"

for img in os.listdir(folder):
    if img.endswith(".jpg"):
        results = model(os.path.join(folder, img))
        print(img, "->", len(results[0].boxes), "bags")
# Out:
# image 1/1 C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v1i.coco\test\03_jpg.rf.28f0f34d85e921076eb357c9235167eb.jpg: 640x640 (no detections), 112.1ms
# Speed: 3.8ms preprocess, 112.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# 03_jpg.rf.28f0f34d85e921076eb357c9235167eb.jpg -> 0 bags
#
# image 1/1 C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v1i.coco\test\05_jpg.rf.7716b4c7132c489a85ace622ce992bff.jpg: 640x640 (no detections), 128.5ms
# Speed: 3.2ms preprocess, 128.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# 05_jpg.rf.7716b4c7132c489a85ace622ce992bff.jpg -> 0 bags
#
# image 1/1 C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v1i.coco\test\10_jpg.rf.1f2384f6f130c4347e18d591b7aa5079.jpg: 640x640 (no detections), 112.0ms
# Speed: 4.5ms preprocess, 112.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# 10_jpg.rf.1f2384f6f130c4347e18d591b7aa5079.jpg -> 0 bags
#
# ...

# %%
import os

print(os.path.exists(r"C:\Users\ASUS\Documents\AI\smart_rice_system\runs\detect\train\weights\best.pt"))
# Out:
# True

# %%
from ultralytics import YOLO

model = YOLO(r"C:\Users\ASUS\Documents\AI\smart_rice_system\runs\detect\train\weights\best.pt")
print(model.names)
# Out:
# {0: 'gunny_bag'}

# %%
import os

print(os.listdir(r"C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v1i.coco"))
# Out:
# ['.ipynb_checkpoints', 'data.yaml', 'test', 'test.cache', 'train', 'train.cache', '_annotations.coco.json']

# %%
import os

print(os.listdir(r"gunny bags.v2i.yolov11\train"))
# Out:
# ['images', 'labels', 'labels.cache']

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")

model.train(
    data=r"gunny bags.v2i.yolov11\data.yaml",
    epochs=3,
    imgsz=640,



    
    batch=8
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.66 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.56  Python-3.13.5 torch-2.12.0+cpu CPU (11th Gen Intel Core i3-1115G4 @ 3.00GHz)
# ...

# %%
import os

print(os.listdir(r"C:\Users\ASUS\Documents\AI\smart_rice_system\runs\detect\train-2\weights"))
# Out:
# ['best.pt', 'last.pt']

# %%
from ultralytics import YOLO

model = YOLO(
    r"C:\Users\ASUS\Documents\AI\smart_rice_system\runs\detect\train-2\weights\best.pt"
)

results = model.predict(
    source=r"C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v2i.yolov11\test\images",
    save=True,
    conf=0.25
)
# Out:
# image 1/220 C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v2i.yolov11\test\images\03_jpg.rf.28f0f34d85e921076eb357c9235167eb.jpg: 640x640 1 Counting  industry - v1 2024-06-18 6-04am, 153.2ms
# image 2/220 C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v2i.yolov11\test\images\05_jpg.rf.7716b4c7132c489a85ace622ce992bff.jpg: 640x640 11 Counting  industry - v1 2024-06-18 6-04ams, 112.3ms
# image 3/220 C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v2i.yolov11\test\images\10_jpg.rf.1f2384f6f130c4347e18d591b7aa5079.jpg: 640x640 5 Counting  industry - v1 2024-06-18 6-04ams, 110.1ms
# image 4/220 C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v2i.yolov11\test\images\114_jpg.rf.b38b12c8594d311af2d3cb0a4f8161fb.jpg: 640x640 3 Counting  industry - v1 2024-06-18 6-04ams, 103.4ms
# ...

# %%
from ultralytics import YOLO

model = YOLO(
    r"C:\Users\ASUS\Documents\AI\smart_rice_system\runs\detect\train-2\weights\best.pt"
)

results = model.predict(
    source=r"C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v2i.yolov11\test\images",
    save=True,
    conf=0.25
)
# Out:
# image 1/220 C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v2i.yolov11\test\images\03_jpg.rf.28f0f34d85e921076eb357c9235167eb.jpg: 640x640 1 Counting  industry - v1 2024-06-18 6-04am, 152.9ms
# image 2/220 C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v2i.yolov11\test\images\05_jpg.rf.7716b4c7132c489a85ace622ce992bff.jpg: 640x640 11 Counting  industry - v1 2024-06-18 6-04ams, 140.2ms
# image 3/220 C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v2i.yolov11\test\images\10_jpg.rf.1f2384f6f130c4347e18d591b7aa5079.jpg: 640x640 5 Counting  industry - v1 2024-06-18 6-04ams, 108.5ms
# image 4/220 C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v2i.yolov11\test\images\114_jpg.rf.b38b12c8594d311af2d3cb0a4f8161fb.jpg: 640x640 3 Counting  industry - v1 2024-06-18 6-04ams, 106.8ms
# ...

# %%
from ultralytics import YOLO
import os

model = YOLO(
    r"C:\Users\ASUS\Documents\AI\smart_rice_system\runs\detect\train-2\weights\best.pt"
)

folder = r"C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v2i.yolov11\test\images"

for img in os.listdir(folder):
    if img.endswith((".jpg", ".png", ".jpeg")):
        results = model(os.path.join(folder, img))
        count = len(results[0].boxes)
        print(f"{img} -> {count} gunny bags")
# Out:
# image 1/1 C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v2i.yolov11\test\images\03_jpg.rf.28f0f34d85e921076eb357c9235167eb.jpg: 640x640 1 Counting  industry - v1 2024-06-18 6-04am, 115.0ms
# Speed: 7.4ms preprocess, 115.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 03_jpg.rf.28f0f34d85e921076eb357c9235167eb.jpg -> 1 gunny bags
#
# image 1/1 C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v2i.yolov11\test\images\05_jpg.rf.7716b4c7132c489a85ace622ce992bff.jpg: 640x640 11 Counting  industry - v1 2024-06-18 6-04ams, 114.8ms
# Speed: 3.6ms preprocess, 114.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 05_jpg.rf.7716b4c7132c489a85ace622ce992bff.jpg -> 11 gunny bags
#
# image 1/1 C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v2i.yolov11\test\images\10_jpg.rf.1f2384f6f130c4347e18d591b7aa5079.jpg: 640x640 5 Counting  industry - v1 2024-06-18 6-04ams, 113.2ms
# ...

# %%
import os

print(os.listdir(r"C:\Users\ASUS\Documents\AI\smart_rice_system\runs\detect\train-2\weights"))
# Out:
# ['best.pt', 'last.pt']

# %%
from ultralytics import YOLO

model = YOLO(
    r"C:\Users\ASUS\Documents\AI\smart_rice_system\runs\detect\train-2\weights\best.pt"
)

print("Model loaded successfully")
# Out:
# Model loaded successfully

# %%
import os

file = r"C:\Users\ASUS\Documents\AI\smart_rice_system\runs\detect\train-2\weights\best.pt"

print("Size:", os.path.getsize(file))
# Out:
# Size: 5466650

# %%
import os

file = r"C:\Users\ASUS\Documents\AI\smart_rice_system\models\best.pt"

print("Exists:", os.path.exists(file))
print("Size:", os.path.getsize(file))

with open(file, "rb") as f:
    print(f.read(20))
# Out:
# Exists: True
# Size: 156
# b'from ultralytics imp'

# %%
import os

file = r"C:\Users\ASUS\Documents\AI\smart_rice_system\runs\detect\train-2\weights\best.pt"

print(os.path.exists(file))
print(os.path.getsize(file))
# Out:
# True
# 5466650

# %%
import shutil

src = r"C:\Users\ASUS\Documents\AI\smart_rice_system\runs\detect\train-2\weights\best.pt"
dst = r"C:\Users\ASUS\Documents\AI\smart_rice_system\models\best.pt"

shutil.copy(src, dst)

print("Copied successfully")
# Out:
# Copied successfully

# %%
import os

print(os.path.getsize(r"C:\Users\ASUS\Documents\AI\smart_rice_system\models\best.pt"))
# Out:
# 5466650

# %%
from ultralytics import YOLO

model = YOLO(
    r"C:\Users\ASUS\Documents\AI\smart_rice_system\models\best.pt"
)

print("Model Loaded Successfully")
# Out:
# Model Loaded Successfully

# %%
from ultralytics import YOLO

# %%
model = YOLO(
r"C:\Users\ASUS\Documents\AI\smart_rice_system\runs\detect\train-2\weights\best.pt"
)

# %%
image_path = r"C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v2i.yolov11\train\images\10_jpg.rf.61fe38b530dcbf34ab43a2f521f66f1d.jpg"

# %%
results = model.predict(
    source=image_path,
    conf=0.5,
    iou=0.4,
    verbose=False
)

# %%
result = results[0]

total_bags = len(result.boxes)

print("Total Gunny Bags:", total_bags)
# Out:
# Total Gunny Bags: 47

# %%
import matplotlib.pyplot as plt

annotated_image = result.plot()

plt.figure(figsize=(10,8))
plt.imshow(annotated_image[:,:,::-1])
plt.axis("off")
plt.show()

# %%
from ultralytics import YOLO

# %%
model = YOLO(
r"C:\Users\ASUS\Documents\AI\smart_rice_system\runs\detect\train-2\weights\best.pt"
)

# %%
results = model.predict(
    source=image_path,
    conf=0.5,
    iou=0.4
)
# Out:
# image 1/1 C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v2i.yolov11\train\images\10_jpg.rf.61fe38b530dcbf34ab43a2f521f66f1d.jpg: 640x640 47 Counting  industry - v1 2024-06-18 6-04ams, 287.9ms
# Speed: 9.3ms preprocess, 287.9ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)

# %%
from ultralytics import YOLO

# Load model
model = YOLO(
    r"C:\Users\ASUS\Documents\AI\smart_rice_system\runs\detect\train-2\weights\best.pt"
)

# Predict directly from image path
results = model.predict(
    source=r"C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v2i.yolov11\test\images\2_jpg.rf.204350f040ce5982a073ea6473fb2c7f.jpg",
    conf=0.5,
    iou=0.4,
    verbose=False
)

result = results[0]

print("Total Gunny Bags:", len(result.boxes))
# Out:
# Total Gunny Bags: 4

# %%
from ultralytics import YOLO

model = YOLO(
r"C:\Users\ASUS\Documents\AI\smart_rice_system\runs\detect\train-2\weights\best.pt"
)

# %%
from ultralytics import YOLO

# Load your trained model
model = YOLO(
    r"C:\Users\ASUS\Documents\AI\smart_rice_system\runs\detect\train-2\weights\best.pt"
)

# Predict on an image
results = model.predict(
    source=r"C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v2i.yolov11\train\images\162_jpg.rf.59a97ee298b532df5ff87eef8a39d96c.jpg",
    conf=0.5,
    save=True
)

# Count detected bags
print("Total Gunny Bags:", len(results[0].boxes))
# Out:
# image 1/1 C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v2i.yolov11\train\images\162_jpg.rf.59a97ee298b532df5ff87eef8a39d96c.jpg: 640x640 1 Counting  industry - v1 2024-06-18 6-04am, 367.7ms
# Speed: 12.3ms preprocess, 367.7ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\Users\ASUS\Documents\AI\smart_rice_system\runs\detect\predict-3
# Total Gunny Bags: 1

# %%
results = model.predict(
    source= r"C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v2i.yolov11\train\images\162_jpg.rf.59a97ee298b532df5ff87eef8a39d96c.jpg",
    
    conf=0.5,
    save=True
)
# Out:
# image 1/1 C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v2i.yolov11\train\images\162_jpg.rf.59a97ee298b532df5ff87eef8a39d96c.jpg: 640x640 1 Counting  industry - v1 2024-06-18 6-04am, 346.5ms
# Speed: 9.4ms preprocess, 346.5ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\Users\ASUS\Documents\AI\smart_rice_system\runs\detect\predict-3

# %%
from ultralytics import YOLO

model = YOLO(
    r"C:\Users\ASUS\Documents\AI\smart_rice_system\runs\detect\train-2\weights\best.pt"
)

results = model.predict(
    source=r"C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v2i.yolov11\train\images\294738bcd74777192e563_jpg.rf.e9ace56d1b5adf3653bf13f5281d6020.jpg",
    conf=0.5,
    save=True
)

print("Total Gunny Bags:", len(results[0].boxes))
# Out:
# image 1/1 C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v2i.yolov11\train\images\294738bcd74777192e563_jpg.rf.e9ace56d1b5adf3653bf13f5281d6020.jpg: 640x640 106 Counting  industry - v1 2024-06-18 6-04ams, 365.4ms
# Speed: 10.5ms preprocess, 365.4ms inference, 6.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\Users\ASUS\Documents\AI\smart_rice_system\runs\detect\predict-5
# Total Gunny Bags: 106

# %%
import os

folder = r"C:\Users\ASUS\Documents\AI\smart_rice_system\gunny bags.v2i.yolov11\test\images"

for img in os.listdir(folder):
    path = os.path.join(folder, img)

    results = model.predict(
        source=path,
        conf=0.5,
        verbose=False
    )

    count = len(results[0].boxes)

    print(img, ":", count)
# Out:
# 03_jpg.rf.28f0f34d85e921076eb357c9235167eb.jpg : 1
# 05_jpg.rf.7716b4c7132c489a85ace622ce992bff.jpg : 8
# 10_jpg.rf.1f2384f6f130c4347e18d591b7aa5079.jpg : 2
# 114_jpg.rf.b38b12c8594d311af2d3cb0a4f8161fb.jpg : 1
# 115_jpg.rf.3e0b5987745c5c437c27f7c931e9c255.jpg : 1
# 116_jpg.rf.a092c9d3cf10508ddfe1254428fc1a0a.jpg : 1
# 11_jpg.rf.e800a393154fc66390e27b562e96669f.jpg : 4
# 120_jpg.rf.4bff7604a275febe65c396b5e7ce9796.jpg : 1
# 12_jpg.rf.820679fe3411a7023fd5e947220aca56.jpg : 2
# 131_jpg.rf.8e56c968a09afea9ea5c465e7349a2a2.jpg : 1
# 136_jpg.rf.0a50efe7f48c848bb5ebcb0b2f882be9.jpg : 1
# 139_jpg.rf.5d1f42b3e147c1bc8aed4a8b207280ff.jpg : 3
# 144_jpg.rf.d695dfdf4ac16179031da577ba556f33.jpg : 1
# 148_jpg.rf.c0a82125d941d2a8dcf2e12e91086f47.jpg : 1
# 156_jpg.rf.9d520d000474aa9caf459c850e786a68.jpg : 1
# 160_jpg.rf.199c58bd18819a5bb78ed94e6273319d.jpg : 1
# 161_jpg.rf.74906aaf83210c74b5503de285a38daa.jpg : 2
# 162_jpg.rf.b93d71b307495b2356dcab627ae93909.jpg : 1
# ...
